# %%
import requests
from bs4 import BeautifulSoup
import os.path
import numpy as np
import json

BASE_URL = 'https://boards.4channel.org/biz/'

# Fetch and format list of all coin symbols from CoinGeko api
coingeko__coin_list = json.loads(requests.get('https://api.coingecko.com/api/v3/coins/list').text)
coingeko__coin_list = [coin_entry['symbol'].upper() for coin_entry in coingeko__coin_list]

# %%
# List of words to exclude as we do not care about them
stopwords = ['a', 'about', 'above', 'across', 'after', 'afterwards']
stopwords += ['again', 'against', 'all', 'almost', 'alone', 'along']
stopwords += ['already', 'also', 'although', 'always', 'am', 'among']
stopwords += ['amongst', 'amoungst', 'amount', 'an', 'and', 'another']
stopwords += ['any', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere']
stopwords += ['are', 'around', 'as', 'at', 'back', 'be', 'became']
stopwords += ['because', 'become', 'becomes', 'becoming', 'been']
stopwords += ['before', 'beforehand', 'behind', 'being', 'below']
stopwords += ['beside', 'besides', 'between', 'beyond', 'bill', 'both']
stopwords += ['bottom', 'but', 'by', 'call', 'can', 'cannot', 'cant']
stopwords += ['co', 'computer', 'con', 'could', 'couldnt', 'cry', 'de']
stopwords += ['describe', 'i\'m', 'did', 'do', 'done', 'down', 'due']
stopwords += ['during', 'each', 'eg', 'got', 'either', 'eleven', 'else']
stopwords += ['elsewhere', 'empty', 'enough', 'etc', 'even', 'ever']
stopwords += ['every', 'everyone', 'everything', 'everywhere', 'except']
stopwords += ['few', 'fifteen', 'fifty', 'fill', 'find', 'fire', 'first']
stopwords += ['five', 'for', 'former', 'formerly', 'forty', 'found']
stopwords += ['four', 'from', 'front', 'full', 'further', 'get', 'give']
stopwords += ['go', 'had', 'has', 'hasnt', 'have', 'he', 'hence', 'her']
stopwords += ['here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers']
stopwords += ['herself', 'him', 'himself', 'his', 'how', 'however']
stopwords += ['hundred', 'i', 'ie', 'if', 'in', 'inc', 'indeed']
stopwords += ['interest', 'into', 'is', 'it', 'its', 'itself', 'keep']
stopwords += ['last', 'latter', 'latterly', 'least', 'less', 'ltd', 'made']
stopwords += ['many', 'may', 'me', 'meanwhile', 'might', 'mill', 'mine']
stopwords += ['more', 'moreover', 'most', 'mostly', 'move', 'much']
stopwords += ['must', 'my', 'myself', 'name', 'namely', 'neither', 'never']
stopwords += ['nevertheless', 'next', 'nine', 'no', 'nobody', 'none']
stopwords += ['noone', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of']
stopwords += ['off', 'often', 'on','once', 'one', 'only', 'onto', 'or']
stopwords += ['other', 'others', 'otherwise', 'our', 'ours', 'ourselves']
stopwords += ['out', 'over', 'own', 'part', 'per', 'perhaps', 'please']
stopwords += ['put', 'rather', 're', 's', 'same', 'see', 'seem', 'seemed']
stopwords += ['seeming', 'seems', 'serious', 'several', 'she', 'should']
stopwords += ['show', 'side', 'since', 'sincere', 'six', 'sixty', 'so']
stopwords += ['some', 'somehow', 'someone', 'something', 'sometime', 'time']
stopwords += ['sometimes', 'somewhere', 'still', 'such', 'system', 'take']
stopwords += ['ten', 'than', 'that', 'the', 'their', 'them', 'themselves']
stopwords += ['then', 'thence', 'there', 'thereafter', 'thereby']
stopwords += ['therefore', 'therein', 'thereupon', 'these', 'they']
stopwords += ['gonna', 'thin', 'third', 'this', 'those', 'though', 'three']
stopwords += ['three', 'through', 'throughout', 'thru', 'thus', 'to']
stopwords += ['together', 'too', 'top', 'toward', 'towards', 'twelve']
stopwords += ['twenty', 'two', 'un', 'under', 'until', 'up', 'upon']
stopwords += ['us', 'very', 'via', 'was', 'we', 'well', 'were', 'what']
stopwords += ['whatever', 'when', 'whence', 'whenever', 'where', 'day', ]
stopwords += ['whereafter', 'whereas', 'whereby', 'wherein', 'whereupon']
stopwords += ['wherever', 'whether', 'which', 'while', 'whither', 'who']
stopwords += ['whoever', 'whole', 'whom', 'whose', 'why', 'will', 'with']
stopwords += ['within', 'without', 'would', 'yet', 'you', 'your', 'WTF', 'drop', 'gme,', 'gme.']
stopwords += ['yours', 'yourself', 'yourselves', 'shit', 'dip']
stopwords += ['want', 'make', 'think', 'just', 'like', 'going', 'don\'t', 'it\'s']
stopwords += ['dont', 'can\'t', 'im', 'coming', 'right', 'it.', 'know', 'right', 'said', 'does']
stopwords += ['SEC', 'BTC', 'AMC', 'NOK', 'GME', 'BUY', 'DAY', 'TRY', 'fall', 'WSB', 'fuck', 'hype']
stopwords += ['sell', 'buy', 'jew', 'jews', 'bb', 'amd', 'push', 'send', 'hold', 'hodl', 'moon']
stopwords += ['KYC', 'PUT', 'CEO', 'STOP', 'SOLD', 'LOL', 'LOOK', 'FUD', 'pump']
stopwords = [x.upper() for x in stopwords]

# %%
# =========== PRINT METHODS
def printTitle(title):
    print('>>>' + title)
    
def printDone():
    print('...Done!')
    
    
def printPostsRelatingToCoin(target, posts_by_thread_dict):
    target = target.upper()
    for thread_key in posts_by_thread_dict:
        for post in posts_by_thread_dict[thread_key]:
            if target in post.upper():
                print(thread_key)
                print(post + '\n')

# %%
# =========== SCRAPE 4CHAN METHODS

def getAllThreadURLsFromPage(page_soup):
    thread_reply_links = page_soup.find_all('a', attrs={'class': 'replylink'})
    thread_urls = []

    for thread_reply_link in thread_reply_links:
        target_url = BASE_URL + thread_reply_link.attrs['href']
        
        # remove optional end path to avoid duplicates and slug change issues         
        end_path = os.path.split(target_url)[1]
        if end_path.isnumeric():
            thread_urls.append(BASE_URL + thread_reply_link.attrs['href'])
        
    return thread_urls


def getAllMessagesInThread(thread_url):       
    thread_page = requests.get(thread_url)
    thread_page_soup = BeautifulSoup(thread_page.content, 'html.parser')
    thread_post_soup = thread_page_soup.find_all(attrs={'class': 'postMessage'})
    
    thread_post_messages = []

    for thread_post in thread_post_soup:
        thread_post_messages.append(thread_post.get_text())
                        
    return thread_post_messages


# TODO: make requests async to speed up time
def fetchAllPostsFromBiz():
    # fetch threads linked on the home page
    printTitle('fetching home page thread links...')
    home_page = requests.get(BASE_URL)
    home_soup = BeautifulSoup(home_page.content, 'html.parser')
    all_thread_urls = getAllThreadURLsFromPage(home_soup)
    printDone()

    # fetch threads links from all other pages
    for i in range(2, 10):
        printTitle('fetching page ' + str(i) + ' thread links...')
        page = requests.get(BASE_URL)
        soup = BeautifulSoup(page.content, 'html.parser')
        all_thread_urls = all_thread_urls + getAllThreadURLsFromPage(soup)
        printDone()


    # fetch every post from all threads on 4chan 
    all_posts_by_thread_dict = {}
    inc_count = 1
    total_count = len(all_thread_urls)

    for thread_url in all_thread_urls:
        printTitle('fetching thread content ' + str(inc_count) + ' of ' + str(total_count) + ' : ' + thread_url)    
        specific_thread_messages = getAllMessagesInThread(thread_url)
        all_posts_by_thread_dict[thread_url] = specific_thread_messages
        inc_count += 1
        printDone()
    
    return all_posts_by_thread_dict

# %%
# =========== DATA CLEANING AN CALCULATION 

def getPotentialTickerWords(sentance):
    # TODO: can probably be removed as we are now comparing against coingeko tickers     
    wordlist = sentance.split()
    wordlist = [w for w in wordlist if len(w) < 6 and len(w) > 2] # no ticker longer than 5
    wordlist = [w for w in wordlist if w.isupper()]
    wordlist = [word.replace(".", "") for word in wordlist]
    wordlist = [w for w in wordlist if w not in stopwords] # remove stop words
    
    return wordlist

def filterByOnCoinGeko(word_list):
    return [w for w in word_list if w not in coingeko__coin_list]

def calculateWordFreq(wordlist, word_freq = {}):
    for word in wordlist:
        if word in word_freq:
            word_freq[word] = word_freq[word] + 1
        else:
            word_freq[word] = 1
            
    return word_freq


def sortFreqDict(freqdict):
    aux = [(freqdict[key], key) for key in freqdict]
    aux.sort()
    aux.reverse()
    return aux


def flattenPostContent(content_of_threads_on_page):
    all_posts_flattened = []
    
    for thread_key in content_of_threads_on_page:
        for post in content_of_threads_on_page[thread_key]:
            all_posts_flattened.append(post)
            
    return all_posts_flattened


def calculateCoinOccurencyFrequency(list_of_posts):
    coin_freq_dict = {}

    for sentance in list_of_posts:
        potential_tickers = getPotentialTickerWords(sentance)
        confirmed_tickers = filterByOnCoinGeko(potential_tickers)
        coin_freq_dict = calculateWordFreq(potential_tickers, coin_freq_dict)
        
    return coin_freq_dict

# %%
# ========== MAIN

# fetch every post from /biz/ returning a dict with the format
# { <thread url>: ['message 1', message2]}
all_posts_by_thread_dict = fetchAllPostsFromBiz()    

# flatten messages into a 1D array of strings (the post content)
all_posts_flattened = flattenPostContent(content_of_threads_on_page)

# Find coin tickers, calculate their frequency and sort by freq
coin_freq_dict = sortFreqDict(calculateCoinOccurencyFrequency(all_posts_flattened))

# Print top 10 coins
for entry in coin_freq_dict[0:10]:
    print(entry)

# Print posts about the top coin
top_rated_coin_ticker = coin_freq_dict[0][1]
printTitle('Printing messages related to most mentiond coin: ' + top_rated_coin_ticker)
printPostsRelatingToCoin(top_rated_coin_ticker, all_posts_by_thread_dict)
# Out:
# >>>fetching home page thread links...
# ...Done!
# >>>fetching page 2 thread links...
# ...Done!
# >>>fetching page 3 thread links...
# ...Done!
# >>>fetching page 4 thread links...
# ...Done!
# >>>fetching page 5 thread links...
# ...Done!
# >>>fetching page 6 thread links...
# ...Done!
# >>>fetching page 7 thread links...
# ...Done!
# >>>fetching page 8 thread links...
# ...Done!
# >>>fetching page 9 thread links...
# ...Done!
# >>>fetching thread content 1 of 128 : https://boards.4channel.org/biz/thread/27154073
# ...Done!
# >>>fetching thread content 2 of 128 : https://boards.4channel.org/biz/thread/27159445
# ...Done!
# >>>fetching thread content 3 of 128 : https://boards.4channel.org/biz/thread/27155793
# ...Done!
# >>>fetching thread content 4 of 128 : https://boards.4channel.org/biz/thread/27153342
# ...Done!
# >>>fetching thread content 5 of 128 : https://boards.4channel.org/biz/thread/27132311
# ...Done!
# >>>fetching thread content 6 of 128 : https://boards.4channel.org/biz/thread/27158462
# ...Done!
# >>>fetching thread content 7 of 128 : https://boards.4channel.org/biz/thread/27158163
# ...Done!
# >>>fetching thread content 8 of 128 : https://boards.4channel.org/biz/thread/27148953
# ...Done!
# >>>fetching thread content 9 of 128 : https://boards.4channel.org/biz/thread/27157856
# ...Done!
# >>>fetching thread content 10 of 128 : https://boards.4channel.org/biz/thread/27145030
# ...Done!
# >>>fetching thread content 11 of 128 : https://boards.4channel.org/biz/thread/27155426
# ...Done!
# >>>fetching thread content 12 of 128 : https://boards.4channel.org/biz/thread/27152840
# ...Done!
# >>>fetching thread content 13 of 128 : https://boards.4channel.org/biz/thread/27158128
# ...Done!
# >>>fetching thread content 14 of 128 : https://boards.4channel.org/biz/thread/27152162
# ...Done!
# >>>fetching thread content 15 of 128 : https://boards.4channel.org/biz/thread/27160029
# ...Done!
# >>>fetching thread content 16 of 128 : https://boards.4channel.org/biz/thread/27154073
# ...Done!
# >>>fetching thread content 17 of 128 : https://boards.4channel.org/biz/thread/27159445
# ...Done!
# >>>fetching thread content 18 of 128 : https://boards.4channel.org/biz/thread/27155793
# ...Done!
# >>>fetching thread content 19 of 128 : https://boards.4channel.org/biz/thread/27153342
# ...Done!
# >>>fetching thread content 20 of 128 : https://boards.4channel.org/biz/thread/27132311
# ...Done!
# >>>fetching thread content 21 of 128 : https://boards.4channel.org/biz/thread/27158462
# ...Done!
# >>>fetching thread content 22 of 128 : https://boards.4channel.org/biz/thread/27158163
# ...Done!
# >>>fetching thread content 23 of 128 : https://boards.4channel.org/biz/thread/27148953
# ...Done!
# >>>fetching thread content 24 of 128 : https://boards.4channel.org/biz/thread/27157856
# ...Done!
# >>>fetching thread content 25 of 128 : https://boards.4channel.org/biz/thread/27145030
# ...Done!
# >>>fetching thread content 26 of 128 : https://boards.4channel.org/biz/thread/27155426
# ...Done!
# >>>fetching thread content 27 of 128 : https://boards.4channel.org/biz/thread/27152840
# ...Done!
# >>>fetching thread content 28 of 128 : https://boards.4channel.org/biz/thread/27158128
# ...Done!
# >>>fetching thread content 29 of 128 : https://boards.4channel.org/biz/thread/27152162
# ...Done!
# >>>fetching thread content 30 of 128 : https://boards.4channel.org/biz/thread/27160029
# ...Done!
# >>>fetching thread content 31 of 128 : https://boards.4channel.org/biz/thread/27159445
# ...Done!
# >>>fetching thread content 32 of 128 : https://boards.4channel.org/biz/thread/27154073
# ...Done!
# >>>fetching thread content 33 of 128 : https://boards.4channel.org/biz/thread/27155793
# ...Done!
# >>>fetching thread content 34 of 128 : https://boards.4channel.org/biz/thread/27153342
# ...Done!
# >>>fetching thread content 35 of 128 : https://boards.4channel.org/biz/thread/27132311
# ...Done!
# >>>fetching thread content 36 of 128 : https://boards.4channel.org/biz/thread/27158462
# ...Done!
# >>>fetching thread content 37 of 128 : https://boards.4channel.org/biz/thread/27158163
# ...Done!
# >>>fetching thread content 38 of 128 : https://boards.4channel.org/biz/thread/27148953
# ...Done!
# >>>fetching thread content 39 of 128 : https://boards.4channel.org/biz/thread/27157856
# ...Done!
# >>>fetching thread content 40 of 128 : https://boards.4channel.org/biz/thread/27145030
# ...Done!
# >>>fetching thread content 41 of 128 : https://boards.4channel.org/biz/thread/27155426
# ...Done!
# >>>fetching thread content 42 of 128 : https://boards.4channel.org/biz/thread/27152840
# ...Done!
# >>>fetching thread content 43 of 128 : https://boards.4channel.org/biz/thread/27152162
# ...Done!
# >>>fetching thread content 44 of 128 : https://boards.4channel.org/biz/thread/27158128
# ...Done!
# >>>fetching thread content 45 of 128 : https://boards.4channel.org/biz/thread/27160029
# ...Done!
# >>>fetching thread content 46 of 128 : https://boards.4channel.org/biz/thread/27159445
# ...Done!
# >>>fetching thread content 47 of 128 : https://boards.4channel.org/biz/thread/27154073
# ...Done!
# >>>fetching thread content 48 of 128 : https://boards.4channel.org/biz/thread/27155793
# ...Done!
# >>>fetching thread content 49 of 128 : https://boards.4channel.org/biz/thread/27153342
# ...Done!
# >>>fetching thread content 50 of 128 : https://boards.4channel.org/biz/thread/27132311
# ...Done!
# >>>fetching thread content 51 of 128 : https://boards.4channel.org/biz/thread/27158462
# ...Done!
# >>>fetching thread content 52 of 128 : https://boards.4channel.org/biz/thread/27158163
# ...Done!
# >>>fetching thread content 53 of 128 : https://boards.4channel.org/biz/thread/27148953
# ...Done!
# >>>fetching thread content 54 of 128 : https://boards.4channel.org/biz/thread/27157856
# ...Done!
# >>>fetching thread content 55 of 128 : https://boards.4channel.org/biz/thread/27145030
# ...Done!
# >>>fetching thread content 56 of 128 : https://boards.4channel.org/biz/thread/27155426
# ...Done!
# >>>fetching thread content 57 of 128 : https://boards.4channel.org/biz/thread/27152840
# ...Done!
# >>>fetching thread content 58 of 128 : https://boards.4channel.org/biz/thread/27152162
# ...Done!
# >>>fetching thread content 59 of 128 : https://boards.4channel.org/biz/thread/27158128
# ...Done!
# >>>fetching thread content 60 of 128 : https://boards.4channel.org/biz/thread/27160029
# ...Done!
# >>>fetching thread content 61 of 128 : https://boards.4channel.org/biz/thread/27158462
# ...Done!
# >>>fetching thread content 62 of 128 : https://boards.4channel.org/biz/thread/27158163
# ...Done!
# >>>fetching thread content 63 of 128 : https://boards.4channel.org/biz/thread/27148953
# ...Done!
# >>>fetching thread content 64 of 128 : https://boards.4channel.org/biz/thread/27157856
# ...Done!
# >>>fetching thread content 65 of 128 : https://boards.4channel.org/biz/thread/27145030
# ...Done!
# >>>fetching thread content 66 of 128 : https://boards.4channel.org/biz/thread/27155426
# ...Done!
# >>>fetching thread content 67 of 128 : https://boards.4channel.org/biz/thread/27153342
# ...Done!
# >>>fetching thread content 68 of 128 : https://boards.4channel.org/biz/thread/27152840
# ...Done!
# >>>fetching thread content 69 of 128 : https://boards.4channel.org/biz/thread/27158128
# ...Done!
# >>>fetching thread content 70 of 128 : https://boards.4channel.org/biz/thread/27152162
# ...Done!
# >>>fetching thread content 71 of 128 : https://boards.4channel.org/biz/thread/27160029
# ...Done!
# >>>fetching thread content 72 of 128 : https://boards.4channel.org/biz/thread/27160381
# ...Done!
# >>>fetching thread content 73 of 128 : https://boards.4channel.org/biz/thread/27135765
# ...Done!
# >>>fetching thread content 74 of 128 : https://boards.4channel.org/biz/thread/27159823
# ...Done!
# >>>fetching thread content 75 of 128 : https://boards.4channel.org/biz/thread/27160306
# ...Done!
# >>>fetching thread content 76 of 128 : https://boards.4channel.org/biz/thread/27154033
# ...Done!
# >>>fetching thread content 77 of 128 : https://boards.4channel.org/biz/thread/27159445
# ...Done!
# >>>fetching thread content 78 of 128 : https://boards.4channel.org/biz/thread/27154073
# ...Done!
# >>>fetching thread content 79 of 128 : https://boards.4channel.org/biz/thread/27153342
# ...Done!
# >>>fetching thread content 80 of 128 : https://boards.4channel.org/biz/thread/27155793
# ...Done!
# >>>fetching thread content 81 of 128 : https://boards.4channel.org/biz/thread/27132311
# ...Done!
# >>>fetching thread content 82 of 128 : https://boards.4channel.org/biz/thread/27158462
# ...Done!
# >>>fetching thread content 83 of 128 : https://boards.4channel.org/biz/thread/27158163
# ...Done!
# >>>fetching thread content 84 of 128 : https://boards.4channel.org/biz/thread/27148953
# ...Done!
# >>>fetching thread content 85 of 128 : https://boards.4channel.org/biz/thread/27157856
# ...Done!
# >>>fetching thread content 86 of 128 : https://boards.4channel.org/biz/thread/27145030
# ...Done!
# >>>fetching thread content 87 of 128 : https://boards.4channel.org/biz/thread/27155426
# ...Done!
# >>>fetching thread content 88 of 128 : https://boards.4channel.org/biz/thread/27160306
# ...Done!
# >>>fetching thread content 89 of 128 : https://boards.4channel.org/biz/thread/27154033
# ...Done!
# >>>fetching thread content 90 of 128 : https://boards.4channel.org/biz/thread/27159445
# ...Done!
# >>>fetching thread content 91 of 128 : https://boards.4channel.org/biz/thread/27154073
# ...Done!
# >>>fetching thread content 92 of 128 : https://boards.4channel.org/biz/thread/27153342
# ...Done!
# >>>fetching thread content 93 of 128 : https://boards.4channel.org/biz/thread/27155793
# ...Done!
# >>>fetching thread content 94 of 128 : https://boards.4channel.org/biz/thread/27132311
# ...Done!
# >>>fetching thread content 95 of 128 : https://boards.4channel.org/biz/thread/27158462
# ...Done!
# >>>fetching thread content 96 of 128 : https://boards.4channel.org/biz/thread/27158163
# ...Done!
# >>>fetching thread content 97 of 128 : https://boards.4channel.org/biz/thread/27148953
# ...Done!
# >>>fetching thread content 98 of 128 : https://boards.4channel.org/biz/thread/27157856
# ...Done!
# >>>fetching thread content 99 of 128 : https://boards.4channel.org/biz/thread/27145030
# ...Done!
# >>>fetching thread content 100 of 128 : https://boards.4channel.org/biz/thread/27155426
# ...Done!
# >>>fetching thread content 101 of 128 : https://boards.4channel.org/biz/thread/27160306
# ...Done!
# >>>fetching thread content 102 of 128 : https://boards.4channel.org/biz/thread/27154033
# ...Done!
# >>>fetching thread content 103 of 128 : https://boards.4channel.org/biz/thread/27159445
# ...Done!
# >>>fetching thread content 104 of 128 : https://boards.4channel.org/biz/thread/27154073
# ...Done!
# >>>fetching thread content 105 of 128 : https://boards.4channel.org/biz/thread/27153342
# ...Done!
# >>>fetching thread content 106 of 128 : https://boards.4channel.org/biz/thread/27155793
# ...Done!
# >>>fetching thread content 107 of 128 : https://boards.4channel.org/biz/thread/27132311
# ...Done!
# >>>fetching thread content 108 of 128 : https://boards.4channel.org/biz/thread/27158462
# ...Done!
# >>>fetching thread content 109 of 128 : https://boards.4channel.org/biz/thread/27158163
# ...Done!
# >>>fetching thread content 110 of 128 : https://boards.4channel.org/biz/thread/27148953
# ...Done!
# >>>fetching thread content 111 of 128 : https://boards.4channel.org/biz/thread/27157856
# ...Done!
# >>>fetching thread content 112 of 128 : https://boards.4channel.org/biz/thread/27145030
# ...Done!
# >>>fetching thread content 113 of 128 : https://boards.4channel.org/biz/thread/27155426
# ...Done!
# >>>fetching thread content 114 of 128 : https://boards.4channel.org/biz/thread/27154073
# ...Done!
# >>>fetching thread content 115 of 128 : https://boards.4channel.org/biz/thread/27159445
# ...Done!
# >>>fetching thread content 116 of 128 : https://boards.4channel.org/biz/thread/27155793
# ...Done!
# >>>fetching thread content 117 of 128 : https://boards.4channel.org/biz/thread/27153342
# ...Done!
# >>>fetching thread content 118 of 128 : https://boards.4channel.org/biz/thread/27132311
# ...Done!
# >>>fetching thread content 119 of 128 : https://boards.4channel.org/biz/thread/27158462
# ...Done!
# >>>fetching thread content 120 of 128 : https://boards.4channel.org/biz/thread/27158163
# ...Done!
# >>>fetching thread content 121 of 128 : https://boards.4channel.org/biz/thread/27148953
# ...Done!
# >>>fetching thread content 122 of 128 : https://boards.4channel.org/biz/thread/27157856
# ...Done!
# >>>fetching thread content 123 of 128 : https://boards.4channel.org/biz/thread/27145030
# ...Done!
# >>>fetching thread content 124 of 128 : https://boards.4channel.org/biz/thread/27155426
# ...Done!
# >>>fetching thread content 125 of 128 : https://boards.4channel.org/biz/thread/27152840
# ...Done!
# >>>fetching thread content 126 of 128 : https://boards.4channel.org/biz/thread/27158128
# ...Done!
# >>>fetching thread content 127 of 128 : https://boards.4channel.org/biz/thread/27152162
# ...Done!
# >>>fetching thread content 128 of 128 : https://boards.4channel.org/biz/thread/27160029
# ...Done!
# (15, 'ETH')
# (13, 'XRP')
# (13, 'FTM')
# (9, 'MUSE')
# (9, 'LINK')
# (8, 'DOGE')
# (5, 'USD')
# (5, 'SHIBA')
# (5, 'SHIB')
# (5, 'RBC')
# >>>Printing messages related to most mentiond coin: ETH
# https://boards.4channel.org/biz/thread/27154073
# Shib pump and dump whale addresses:https://etherscan.io/tokentxns?a=0x7864aabd2941ff47eefc4d3c50246c4b3fa475dehttps://etherscan.io/tokentxns?a=0x00000000cd47aa64daf64f5144b0d7885754374c&p=1https://etherscan.io/tokentxns?a=0xd82724a01bce06bbc3face916bd14b5b06ef59bdThese guys can dump on you at any moment
#
# https://boards.4channel.org/biz/thread/27154073
# Trying to buy on UNI but it keeps failing. Yes, I have enough ETH for gas fees. What the hell?
#
# https://boards.4channel.org/biz/thread/27154073
# >>27160012god i want to believe. how long do you think it will take for it to hit its cap? I need it to go at minimum 3-5x just to make my tiny buy in actually worth the gas to pull it back out to ETH.
#
# https://boards.4channel.org/biz/thread/27159445
# >>27159795Ya that’s true but it happened to eth and you see what happened. Normies suck tho it’s still our coin for sure
#
# https://boards.4channel.org/biz/thread/27155793
# >>27155793ETH pamp soon? Roll, check'em dubs
#
# https://boards.4channel.org/biz/thread/27155793
# When the fuck is ETH going to pump? Literally everything has pumped including BTC. When is ETH going to finally break above its all time high?
#
# https://boards.4channel.org/biz/thread/27153342
# >>27153342here's a pro tip: holding something doesn't make the price go up. quite the opposite.
#
# https://boards.4channel.org/biz/thread/27153342
# I'm a bag holder and glad it's tanking. I threw 100 bucks at it. Would be nice to see it hit something high but oh well. I can cope by saying I spent 100 bucks on entertainment as I'll see a sea of pink wojaks and redditor soijaks jumping off roofs for their dumbass tendencies
#
# https://boards.4channel.org/biz/thread/27153342
# >>27157782that would be like almost the MC of ethereum.nice cool way to literally crash crypto for 3 years
#
# https://boards.4channel.org/biz/thread/27153342
# >>27153342There's something about crypto that normies just never learn.
#
# https://boards.4channel.org/biz/thread/27153342
# >>27158210It'll pump again later this year. We haven't really seen a true alt season yet. Hopefully you don't have too much in it though because checking its price is going to be brutal. Also, hopefully you didn't buy the literal top. Gl anon, only buy doge when it's under 1 cent and don't buy something once reddit and co coordinate to buy it
#
# https://boards.4channel.org/biz/thread/27132311
# >>27134207btc has transactions fees, but they are not called gas fees, that's ethereum stuffUNRELATED QUESTION READ FIRST POST, BUY BTC
#
# https://boards.4channel.org/biz/thread/27132311
# >>27137412Ok Keiser. I will follow cautiously.I have $200 to throw today. I am contemplating if I should do ETH or BTC.
#
# https://boards.4channel.org/biz/thread/27132311
# >>27138532based forbidden knowledge knower. this is finally putting the pieces together in my mind
#
# https://boards.4channel.org/biz/thread/27132311
# >>27139374do you assume normie are still holding? they already panic sold at 29k, and 2017 fags already learned how to manage the swingsnow it's smart money accumulating BTC whatever happens, whatever is the price34k? cheap as fuckone day you will regret for not doing soreally, nothing clicks in your mind?WEMAKETHEPRICE
#
# https://boards.4channel.org/biz/thread/27132311
# >>27140387can they confiscate it?nope, and you can use CoinJoinif you have surgeries, you should not gamble this money, health first frenBTC is for the long term, if you don't keep them for 10 years you are doing something wrong>>27140416doge and tron are pump and dumpswhen we buy BTC, we buy them to keep them forever
#
# https://boards.4channel.org/biz/thread/27132311
# I'm waiting for doge to rebound a little and i'll convert it to BTC and ETH.
#
# https://boards.4channel.org/biz/thread/27132311
# BTC is too slow. They've had a decade to sort out the transaction speeds.It needs to be ETH
#
# https://boards.4channel.org/biz/thread/27132311
# >>27143993>Why do you think they promote bitcoin on the msm now????are you retarded?lagarde and yellen are saying it is used by criminals, tether fud all over the news, "btc was hacked" all over the newsyou are really a motherfucking moronkikes don't control btc supplyif you want to buy PM, good, do it, but don't shit on btc retard
#
# https://boards.4channel.org/biz/thread/27132311
# >everyone go into bitcoin, which could crash by 90% at a moment's notice, with your emergency expensesFuck that, how about we purchase physical silver and double fuck the jews while actually having something of tangible value.
#
# https://boards.4channel.org/biz/thread/27132311
# >>27157250metamask is for eth only>>27157333they are both scamsjust buy and don't use leveragesI REPEATDONOTUSELEVERAGESjust buy btc and that's fucking it
#
# https://boards.4channel.org/biz/thread/27132311
# >>27132311thats a potential date for the Jesuit Order to trigger the great resethttps://gematriaeffect.news/valentines-day-2021-in-light-of-klaus-schwab-the-great-reset-the-world-economic-forum/https://gematriaeffect.news/biden-enters-u-s-back-into-paris-agreement-and-opts-out-of-keystone-xl-pipeline-january-20-2021/https://gematriaeffect.news/world-economic-forum-announces-the-great-reset-for-january-2021/https://gematriaeffect.news/utopias-janus-bill-gates-good-club-the-plan-to-depopulate-by-stopping-human-fertility-in-plain-sight/https://gematriaeffect.news/mosquito-week-grim-reaper-bill-gates-august-17-2020-post-on-youtube/
#
# https://boards.4channel.org/biz/thread/27132311
# >>27157759Fuck, your right. I only invest in link and eth with the occasional moonshoot gamble.
#
# https://boards.4channel.org/biz/thread/27148953
# >>27148953>If the graphs maximum supply were in circulation right now at the same market cap, 1 graph would be 7.5 cents>In 5 months when the first large token drop hits it will triple the supply. If the market cap stays the same 1 graph would be 17.2 cents>In 1 year we will have 6 trillion tokens in circulation. At the current market cap 1 graph would be 12.9 cents>If the market cap were what chainlinks is right now, after the first token drop 1 graph would be $2.07>If the market cap were what eth's is right now, with max tokens in circulation (which will take 5 years and all of these mcaps will be much higher) 1 graph would be $15.59We will see $10 graph within 2 years
#
# https://boards.4channel.org/biz/thread/27157856
# Anyone on coinspot notice a bot selling the same price as the lowest selling order and also buying at the highest buying order? Would this method actually make you rich?
#
# https://boards.4channel.org/biz/thread/27157856
# >>27157760>no big announcement.ripple completely wrecked SEC in their newest updatei got the news to my phone like 18 hours ago or something and i knew that itd pump later lol
#
# https://boards.4channel.org/biz/thread/27157856
# 1.25B USDT volume for the past hours alone on Binance. I don't think retail has that much money. The big players know something we don't. If you sell now, you are unironically NGMI.
#
# https://boards.4channel.org/biz/thread/27157856
# >>27159285(((They))) are monitoring "unusual" investing activity now. You're not allowed to buy in something if buyers are gonna make money
#
# https://boards.4channel.org/biz/thread/27157856
# >>27159482HAHAHAHAHAHAHA SEETHE FKN FAGGOT
#
# https://boards.4channel.org/biz/thread/27145030
# get in here lads, first general. Post stats, facts and any writefags give us some nice greentexts of the situation, anyone good at infographics lets put this all together for leddit.
#
# https://boards.4channel.org/biz/thread/27145030
# Reposting my post from end of last thread. For all the fools talking about confiscation of pm that would only work somewhere like China now. Not because they are totalitarian. But because enough of the population there have private ownership. There is not enough private ownership in the US atm to make seizure accomplish anything. So its a non point.For those asking about buying pm with crypto most bullion banks accept BTC, bitcoin cash, ETH, XRP and some others occasionally. You just got to ask.T- work in pm
#
# https://boards.4channel.org/biz/thread/27145030
# >>27147357How does any of that relate to silver price?I'm just pointing out that Max is a cheap huckster that has pumped silver beforeThe silver shorts shit all over him and he lost all credibility
#
# https://boards.4channel.org/biz/thread/27145030
# >>27147895this is based, this is the kind of stuff we need in the op for these generals, and some photoshop anons need to be putting this all together in reddit friendly infographics, thanks for the post anon
#
# https://boards.4channel.org/biz/thread/27145030
# The new friends don’t understand there are 8000+ crypto’s and most of them are pump and dumps forked in a day by Indians most designed to be shilled on biz for a week max Gold and silver are foreverAnd anyone that knows anything about crypto knows that bitcoin can’t scale and will be left In the dust when the technology is perfected and they will have to peg the new coin to something and I hope to god it’s not the USD
#
# https://boards.4channel.org/biz/thread/27145030
# Boomers around the office think I can do no wrong in the market now, they were so skeptical about GME and other meme stocks. When the silver squeeze is explained to a boomer something different happens than when you explain the Gamestop situation... they get it.One of the higher ups moved his modest trading account over. One of the owners came to be because he's bleeding in his boomer index funds and he needs to put a million somewhere "safe". This silver thing is going to work, but the time hasn't come yet. Keep accumulating SLV or physical and wait.
#
# https://boards.4channel.org/biz/thread/27145030
# Physical silver is something everyone should be holding, but emptying retail inventory is NOT going to trigger any squeezes. But everyone buying PSLV like they did GME (and definitely options) will force Eric Sprott to have to go stand for delivery on COMEX in order to rebalance the fund. Him taking large delivery definitely could contribute to a squeeze. So PSLV is really the pain point. It's why Robinhood has delisted it while you can still get SLV. SLV is a scam and thy will issue as much paper to soak up the attack without every needing physical. PSLV is legit and if there is enough demand for it, Sprott WILL stand for massive delivery and put big pressure on COMEX.
#
# https://boards.4channel.org/biz/thread/27145030
# I'm back made $$$$ yesterday on a shit Stonk SIEB something like 500% gains. All I know its something financial, but the same old average and pattern!! Now that the dust has settled let's play the Silver squeeze or die trying to get rich. Im dumping $150 K Monday in Silver the average investors are selling to cut losses, their loss our gain!! Also the big companies are dumping stock to cut losses!! Don't buy Silver jewelry its a con game with no return!! Plain Silver bullion is where its at for physical Silver. Stocks and options are going to run like drugged whores from cops!! Anyways somebody gone buy, while the others gone cry!! Lets help ourselves and rob the fat cats for a change!! Buy with stop loss orders, but spread it among a bunch of American and EU STONKS they are easy to liquidate compared to other markets. Enjoy the ride this week !!! Buy plain bullion silver rounds they wont price gouge you as much as rounds with a design on them!!
#
# https://boards.4channel.org/biz/thread/27155426
# >>27155426Alright usually people think their keys are unrecoverable but there is something people don't know. In order to recover your keys you will have to follow each of the following steps word-for-word, any deviation will result in your keys being lost forever. First I need you to ensure that you can follow each of the instructions I can lay out carefully; and maintain your composure in being able to determine when you are unable to follow these instructions. Losing your composure in determining when you are unable to determine when you cannot follow these instructions can spell mishap; I repeat mishap. Alright so now that you're ready; I want you to get on your knees and suck a nigger cock. Cheers!
#
# https://boards.4channel.org/biz/thread/27155426
# haha i have 7eth i bought in 2012 in a wallet, i can go to the blickchain and see it but hace no way to get it, so dont feel to bad bro
#
# https://boards.4channel.org/biz/thread/27155426
# >>27158239eth didn't existed in 2012 you god damn mongoloid
#
# https://boards.4channel.org/biz/thread/27152840
# >>27152840Why would you make your living off something you're bad at? Isn't that super irresponsible of you?>but I'm good with stocksClearly not since you don't know how to handle traction
#
# https://boards.4channel.org/biz/thread/27152840
# >>27153866unless im missing something or she is well over 6' 5" there is no way that bitch is over 160her arms and legs are still round not glupe messes no weird neck and her ankles are normal.
#
# https://boards.4channel.org/biz/thread/27152840
# >>27152840Maybe you should get a real job that actually requires effort and contributes something to your community rather than trying to abuse an exploit in capitalism.
#
# https://boards.4channel.org/biz/thread/27158128
# >>27159253What are you moving to anon? I moved to Fidelity but I think I want something with a less boomer UI
#
# https://boards.4channel.org/biz/thread/27158128
# >>27159237I'm not even posting plays here anymore because the only way to win is to quietly accumulate before something becomes a meme and all the algos that scrape these threads pick it up and all the movement happens pre-market.
#
# https://boards.4channel.org/biz/thread/27158128
# >>27159337>100 Billion in profits last quarter (during a Pandemic)One could argue it was because of the pandemic with work at home be the new normal and everyone buying hardwareThough I agree M1 is smokingI’m and always have been long aapl it will be the first 10 trillion 2K+ Shares hodl 4eva
#
# https://boards.4channel.org/biz/thread/27158128
# >>27160150That's funny but I just can't imagine the SEC making some kind of real case against literally 10's of millions of randos on the internet. Especially when this whole thing has such insane populist support across the whole political spectrum. When AOC and Ted Cruz agree on something you can bet the SEC will be damn careful about running against it
#
# https://boards.4channel.org/biz/thread/27158128
# Thoughts on NVDA rn bros? IMO it seems too overvalued, is there something I'm missing?
#
# https://boards.4channel.org/biz/thread/27158128
# Ok, so maybe the Melvin guys weren't really lying. The Ortex data showing short interest drop from 1/26 to 1/27 coinciding with the massive and sudden price dislocation upward on 1/27.If new shorts entered the game it would have been near the highs, possibly selling into the forced buying of what I'll just assume was the overnight Melvin squeeze and into the early market hours on 1/28. Possibly aggressive momentum shorting on top of the Robin Hood BS, the bots, and the networking issues came together in a perfect storm with that HFT ladder attack on the vertical dive. Wow--no wonder that thing was so intense.
#
# https://boards.4channel.org/biz/thread/27158128
# >>27161032Not allowing users to buy shares but only sell them IMHO is stock manipulation Wether the SEC sees it tht way is another questionThe class action jew dogs are already circling the wounded prey
#
# https://boards.4channel.org/biz/thread/27152162
# >>27152162We ARE doing it, but that notice was there before this GME shit started. Since the beginning of January all the major bullion dealers have been experiencing delays due to increased orders, whether they put a notice up or not.
#
# https://boards.4channel.org/biz/thread/27135765
# I checked the site and video, now waiting on ETH arriving
#
# https://boards.4channel.org/biz/thread/27135765
# >>27141245if ETH pumps now, we'll fly past $150
#
# https://boards.4channel.org/biz/thread/27135765
# >>27146409Rodrigo FerreiraHead Developer BackendAlong with a Ph.D. from Yale, Rodrigo is a computer scientist and software engineer with a background in formal semantics, program verification, and compilers. Rodrigo is deeply interested in cryptocurrencies/blockchain—having developed both a mobile wallet and an exchange.Irving CabelloHead Developer FrontendIrving is a full-stack javascript developer with a strong passion in Ethereum, DeFi and the Blockchain Ecosystem. He has experience building platforms on React and Node for more than 5 years and has developed multiple DAPPS for Ethereum using Solidity, Web3 and
#
# https://boards.4channel.org/biz/thread/27135765
# >>27135765Why would you buy a coin with no value? How often do you go to a store and buy something that adds literally no value to your life? Buy MUSE. It's an in game currency with users who are actively using it every day. The game keeps getting better too. Soon it'll be mainstream
#
# https://boards.4channel.org/biz/thread/27135765
# >>27148611Have you tried buying ETH right inside metamask wallet? You can do that or sign up on crypto.com and link your debit card and buy there also..
#
# https://boards.4channel.org/biz/thread/27135765
# >>27149193I believe the chap is new and needs to get ETH to buy GRO with... Wise move if you ask me...GRO to pluto and MARS...
#
# https://boards.4channel.org/biz/thread/27135765
# >>27149548I got GRO,ETH and AAVE waiting
#
# https://boards.4channel.org/biz/thread/27135765
# >>27151318The worst attitude is to think you’re too late on something that still has 10-30x potential. Definitely DYOR, but the rocket hasn’t even taken off imo
#
# https://boards.4channel.org/biz/thread/27135765
# >>27155705I'm a moderately poorfag though, I have to plan my buys really carefully. I don't think I'm going to be able get into this until it hits some crazy price. I would just DCA some tokens but the only place I think I can get it is on Uniswap and ETH gas fees are raping my wallet lately.
#
# https://boards.4channel.org/biz/thread/27135765
# >>27155990DCA is the way to go, there has been two big dips, but they where bought back up pretty quick. I always keep an eye on gas at ethgasstation.info if it's low and a dip comes I'd buy. Any exchange can list it, but the team aren't seeking it currently.
#
# https://boards.4channel.org/biz/thread/27135765
# >>27160334im waiting for an eth dip but i dunno
#
# https://boards.4channel.org/biz/thread/27160306
# Imagine not buying the japanese ethereum >kek Join now or cry later
#
# https://boards.4channel.org/biz/thread/27154033
# I sold at $3, threw that Eth into some shit coin, all gone. Dumbest move I've ever made.
#
# https://boards.4channel.org/biz/thread/27154033
# >>27155138dont feel bad about it, the dump never ended. it is what it is. i'm not buying this pump. i won't get dumped on twice. ETH will save me.
#
# https://boards.4channel.org/biz/thread/27154033
# >>27157450on the long term you can expect at least a x2 from hereon the short term, it's about to bounce back its upper trend, it's a good time to sell for ETH (which might break ATH resistance soon)
#
# https://boards.4channel.org/biz/thread/27154033
# >>27159613I think 18.25, I just swapped my ETH.
#
# https://boards.4channel.org/biz/thread/27154033
# >sold 350 of it for ETH at 2 dollarsA-A-Atleast I have 50 still
#
# https://boards.4channel.org/biz/thread/27154033
# >>27160130Sorry Anon, you missed it if you didn't meet the following criteria:>The snapshot was taken on 11/23/2020 at 00:00 UTC+0 and if you had at least 100 UNI during the snapshot, then you will receive 220 MIR tokens.for the rest of you, go claim your free $1,000 here: https://eth.mirror.finance/airdrop
#
# https://boards.4channel.org/biz/thread/27154033
# >>27160252Yeah, so anon is eligible: https://eth.mirror.finance/airdrop
