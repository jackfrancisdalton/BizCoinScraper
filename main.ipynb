# %%
import requests
from bs4 import BeautifulSoup
import os.path
import numpy as np
import json
import re

BASE_URL = 'https://boards.4channel.org/biz/'

# Fetch and format list of all coin symbols from CoinGeko api
coingeko__coin_list = json.loads(requests.get('https://api.coingecko.com/api/v3/coins/list').text)
coingeko__coin_list = [coin_entry['symbol'].upper() for coin_entry in coingeko__coin_list]

# %%
# List of words to exclude as we do not care about them
stopwords = ['a', 'about', 'above', 'across', 'after', 'afterwards']
stopwords += ['again', 'against', 'all', 'almost', 'alone', 'along']
stopwords += ['already', 'also', 'although', 'always', 'am', 'among']
stopwords += ['amongst', 'amoungst', 'amount', 'an', 'and', 'another']
stopwords += ['any', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere']
stopwords += ['are', 'around', 'as', 'at', 'back', 'be', 'became']
stopwords += ['because', 'become', 'becomes', 'becoming', 'been']
stopwords += ['before', 'beforehand', 'behind', 'being', 'below']
stopwords += ['beside', 'besides', 'between', 'beyond', 'bill', 'both']
stopwords += ['bottom', 'but', 'by', 'call', 'can', 'cannot', 'cant']
stopwords += ['co', 'computer', 'con', 'could', 'couldnt', 'cry', 'de']
stopwords += ['describe', 'i\'m', 'did', 'do', 'done', 'down', 'due']
stopwords += ['during', 'each', 'eg', 'got', 'either', 'eleven', 'else']
stopwords += ['elsewhere', 'empty', 'enough', 'etc', 'even', 'ever']
stopwords += ['every', 'everyone', 'everything', 'everywhere', 'except']
stopwords += ['few', 'fifteen', 'fifty', 'fill', 'find', 'fire', 'first']
stopwords += ['five', 'for', 'former', 'formerly', 'forty', 'found']
stopwords += ['four', 'from', 'front', 'full', 'further', 'get', 'give']
stopwords += ['go', 'had', 'has', 'hasnt', 'have', 'he', 'hence', 'her']
stopwords += ['here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers']
stopwords += ['herself', 'him', 'himself', 'his', 'how', 'however']
stopwords += ['hundred', 'i', 'ie', 'if', 'in', 'inc', 'indeed']
stopwords += ['interest', 'into', 'is', 'it', 'its', 'itself', 'keep']
stopwords += ['last', 'latter', 'latterly', 'least', 'less', 'ltd', 'made']
stopwords += ['many', 'may', 'me', 'meanwhile', 'might', 'mill', 'mine']
stopwords += ['more', 'moreover', 'most', 'mostly', 'move', 'much']
stopwords += ['must', 'my', 'myself', 'name', 'namely', 'neither', 'never']
stopwords += ['nevertheless', 'next', 'nine', 'no', 'nobody', 'none']
stopwords += ['noone', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of']
stopwords += ['off', 'often', 'on','once', 'one', 'only', 'onto', 'or']
stopwords += ['other', 'others', 'otherwise', 'our', 'ours', 'ourselves']
stopwords += ['out', 'over', 'own', 'part', 'per', 'perhaps', 'please']
stopwords += ['put', 'rather', 're', 's', 'same', 'see', 'seem', 'seemed']
stopwords += ['seeming', 'seems', 'serious', 'several', 'she', 'should']
stopwords += ['show', 'side', 'since', 'sincere', 'six', 'sixty', 'so']
stopwords += ['some', 'somehow', 'someone', 'something', 'sometime', 'time']
stopwords += ['sometimes', 'somewhere', 'still', 'such', 'system', 'take']
stopwords += ['ten', 'than', 'that', 'the', 'their', 'them', 'themselves']
stopwords += ['then', 'thence', 'there', 'thereafter', 'thereby']
stopwords += ['therefore', 'therein', 'thereupon', 'these', 'they']
stopwords += ['gonna', 'thin', 'third', 'this', 'those', 'though', 'three']
stopwords += ['three', 'through', 'throughout', 'thru', 'thus', 'to']
stopwords += ['together', 'too', 'top', 'toward', 'towards', 'twelve']
stopwords += ['twenty', 'two', 'un', 'under', 'until', 'up', 'upon']
stopwords += ['us', 'very', 'via', 'was', 'we', 'well', 'were', 'what']
stopwords += ['whatever', 'when', 'whence', 'whenever', 'where', 'day', ]
stopwords += ['whereafter', 'whereas', 'whereby', 'wherein', 'whereupon']
stopwords += ['wherever', 'whether', 'which', 'while', 'whither', 'who']
stopwords += ['whoever', 'whole', 'whom', 'whose', 'why', 'will', 'with']
stopwords += ['within', 'without', 'would', 'yet', 'you', 'your', 'WTF', 'drop', 'gme,', 'gme.']
stopwords += ['yours', 'yourself', 'yourselves', 'shit', 'dip']
stopwords += ['want', 'make', 'think', 'just', 'like', 'going', 'don\'t', 'it\'s']
stopwords += ['dont', 'can\'t', 'im', 'coming', 'right', 'it.', 'know', 'right', 'said', 'does']
stopwords += ['SEC', 'BTC', 'AMC', 'NOK', 'GME', 'BUY', 'DAY', 'TRY', 'fall', 'WSB', 'fuck', 'hype']
stopwords += ['sell', 'buy', 'jew', 'jews', 'bb', 'amd', 'push', 'send', 'hold', 'hodl', 'moon']
stopwords += ['KYC', 'PUT', 'CEO', 'STOP', 'SOLD', 'LOL', 'LOOK', 'FUD', 'pump']
stopwords = [x.upper() for x in stopwords]

# %%
# =========== PRINT METHODS
def print_title(title):
    print('>>>' + title)
    
def print_done():
    print('...Done!')
    

def print_posts_mentioning_coin(target, posts_by_thread_dict):
    target = target.upper()
    for thread_key in posts_by_thread_dict:    
        for post in posts_by_thread_dict[thread_key]:
            
            target_found = re.search(rf"\b{target}\b", post, re.IGNORECASE)
            
            if target_found:
                print(thread_key)
                print(post + '\n')

# %%
# =========== SCRAPE 4CHAN METHODS

def fetch_all_thread_urls_from_page(page_soup):
    thread_reply_links = page_soup.find_all('a', attrs={'class': 'replylink'})
    thread_urls = []

    for thread_reply_link in thread_reply_links:
        target_url = BASE_URL + thread_reply_link.attrs['href']
        
        # remove optional end path to avoid duplicates and slug change issues         
        end_path = os.path.split(target_url)[1]
        if end_path.isnumeric():
            thread_urls.append(BASE_URL + thread_reply_link.attrs['href'])
        
    return thread_urls


def fetch_all_posts_from_thread(thread_url):       
    thread_page = requests.get(thread_url)
    thread_page_soup = BeautifulSoup(thread_page.content, 'html.parser')
    thread_post_soup = thread_page_soup.find_all(attrs={'class': 'postMessage'})
    
    all_thread_posts = []

    for thread_post in thread_post_soup:
        all_thread_posts.append(thread_post.get_text())
                        
    return all_thread_posts


# TODO: make requests async to speed up time
def fetch_all_posts_on_biz():
    # fetch threads linked on the home page
    print_title('fetching home page thread links...')
    home_page = requests.get(BASE_URL)
    home_soup = BeautifulSoup(home_page.content, 'html.parser')
    all_thread_urls = fetch_all_thread_urls_from_page(home_soup)
    print_done()

    # fetch threads links from all other pages
    for i in range(2, 10):
        print_title('fetching page ' + str(i) + ' thread links...')
        page = requests.get(BASE_URL)
        soup = BeautifulSoup(page.content, 'html.parser')
        all_thread_urls = all_thread_urls + fetch_all_thread_urls_from_page(soup)
        print_done()


    # fetch every post from all threads on 4chan 
    all_posts_by_thread_dict = {}
    inc_count = 1
    total_count = len(all_thread_urls)

    for thread_url in all_thread_urls:
        print_title('fetching thread content ' + str(inc_count) + ' of ' + str(total_count) + ' : ' + thread_url)    
        specific_thread_messages = fetch_all_posts_from_thread(thread_url)
        all_posts_by_thread_dict[thread_url] = specific_thread_messages
        inc_count += 1
        print_done()
    
    return all_posts_by_thread_dict

# %%
# =========== DATA CLEANING AN CALCULATION 

def filter_for_potential_ticker_references(sentance):
    # TODO: can probably be removed as we are now comparing against coingeko tickers     
    wordlist = sentance.split()
    wordlist = [w for w in wordlist if len(w) < 6 and len(w) > 2] # no ticker longer than 5
    wordlist = [w for w in wordlist if w.isupper()]
    wordlist = [word.replace(".", "") for word in wordlist]
    wordlist = [w for w in wordlist if w not in stopwords] # remove stop words
    
    return wordlist

def filter_for_coins_list_on_coingecko(word_list):
    return [w for w in word_list if w not in coingeko__coin_list]

def calculate_freq_of_word(wordlist, word_freq = {}):
    for word in wordlist:
        if word in word_freq:
            word_freq[word] = word_freq[word] + 1
        else:
            word_freq[word] = 1
            
    return word_freq


def sort_freq_dict(freq_dict):
    aux = [(freq_dict[key], key) for key in freq_dict]
    aux.sort()
    aux.reverse()
    return aux


def flatten_post_by_thread_dict(content_of_threads_on_page):
    all_posts_in_dict = []
    
    for thread_key in content_of_threads_on_page:
        for post in content_of_threads_on_page[thread_key]:
            all_posts_in_dict.append(post)
            
    return all_posts_in_dict


def calculate_freq_of_coin_tickers_in_posts(list_of_posts):
    coin_freq_dict = {}

    for sentance in list_of_posts:
        potential_tickers = filter_for_potential_ticker_references(sentance)
        confirmed_tickers = filter_for_coins_list_on_coingecko(potential_tickers)
        coin_freq_dict = calculate_freq_of_word(potential_tickers, coin_freq_dict)
        
    return coin_freq_dict

# %%
# ========== MAIN

# fetch every post from /biz/ returning a dict with the format
# { <thread url>: ['message 1', message2]}
all_posts_by_thread_dict = fetch_all_posts_on_biz()    

# flatten messages into a 1D array of strings (the post content)
all_posts_flattened = flatten_post_by_thread_dict(all_posts_by_thread_dict)

# Find coin tickers, calculate their frequency and sort by freq
coin_freq_dict = sort_freq_dict(calculate_freq_of_coin_tickers_in_posts(all_posts_flattened))
# Out:
# >>>fetching home page thread links...
# ...Done!
# >>>fetching page 2 thread links...
# ...Done!
# >>>fetching page 3 thread links...
# ...Done!
# >>>fetching page 4 thread links...
# ...Done!
# >>>fetching page 5 thread links...
# ...Done!
# >>>fetching page 6 thread links...
# ...Done!
# >>>fetching page 7 thread links...
# ...Done!
# >>>fetching page 8 thread links...
# ...Done!
# >>>fetching page 9 thread links...
# ...Done!
# >>>fetching thread content 1 of 138 : https://boards.4channel.org/biz/thread/27163480
# ...Done!
# >>>fetching thread content 2 of 138 : https://boards.4channel.org/biz/thread/27159445
# ...Done!
# >>>fetching thread content 3 of 138 : https://boards.4channel.org/biz/thread/27155793
# ...Done!
# ...Done!
# >>>fetching thread content 108 of 138 : https://boards.4channel.org/biz/thread/27164680
# ...Done!
# >>>fetching thread content 109 of 138 : https://boards.4channel.org/biz/thread/27165427
# ...Done!
# >>>fetching thread content 110 of 138 : https://boards.4channel.org/biz/thread/27163480
# ...Done!
# >>>fetching thread content 111 of 138 : https://boards.4channel.org/biz/thread/27158272
# ...Done!
# >>>fetching thread content 112 of 138 : https://boards.4channel.org/biz/thread/27164350
# ...Done!
# >>>fetching thread content 113 of 138 : https://boards.4channel.org/biz/thread/27163360
# ...Done!
# >>>fetching thread content 114 of 138 : https://boards.4channel.org/biz/thread/27160381
# ...Done!
# >>>fetching thread content 115 of 138 : https://boards.4channel.org/biz/thread/27164448
# ...Done!
# >>>fetching thread content 116 of 138 : https://boards.4channel.org/biz/thread/27163571

# %%
# Print top 10 coins
for entry in coin_freq_dict[0:10]:
    print(entry)
# Out:
# (28, 'ETH')
# (19, 'RBC')
# (17, 'LINK')
# (8, 'DOGE')
# (7, 'XRP')
# (7, 'USD')
# (5, 'STOCK')
# (4, 'XLM')
# (4, 'UNI')
# (4, 'GROUP')
# >>>Printing messages related to most mentiond coin: ETH
# https://boards.4channel.org/biz/thread/27160553
# I use XRP and XLM for fast, <$0.01transfers between exchanges as well as to buy bullion (direct buy with XRP) and McDonalds (through Uphold debit card). I also use ETH within the DeFi ecosystem to get better rates on savings than any bank offers.
#
# https://boards.4channel.org/biz/thread/27139211
# Unironically undervalued gem. When RBC reaches at least a marketcap of 1inch, that'd put it at a price of ~$5. But considering that it is cross-chain unlike most of the other DeFi exchange platforms, there is a larger potential for growth + no retarded ETH gas fees
#
# https://boards.4channel.org/biz/thread/27139211
# should i go all in rubic or 50/50 with inj, got about 4 eth to play with
#
# https://boards.4channel.org/biz/thread/27139211
# >>27145586To buy RBC on Uniswap with MetaMask wallet: 1. If necessary, buy ETH with fiat (likely on Coinbase in US, Binance elsewhere).2. Withdraw/send ETH to MetaMask wallet. If this is new to you, google how to download and use MM wallet.3. Watch first half of 10 minute youtube video titled: “UniSwap Tutorial 2021…”4. Connect MM wallet to Uniswap.5. Go to coingecko, search for Rubic, copy the contract address for RBC — should look like “0x…3e3”. While here, scroll down to markets and take note of how you might look for where to buy other tokens/currency in the future so you don’t look so retarded.6. Paste the address into the “select token” search on uniswap.7. Buy the token.8. You won't immediately see the token in your wallet, you must scroll to the bottom of your MM wallet screen and click “add token”.9. Click “custom token”, paste RBC address, click “next” and then “add tokens”.10. Collect and post Rubic memes and complain about gas fees.
#
# https://boards.4channel.org/biz/thread/27139211
# >>27145586) Go to metamask and follow all instructions to make a wallet2) Send ETH from coinbase to your metamask wallet3) Click add token, custom token, paste this contract 0xa4eed63db85311e22df4473f87ccfc3dadcfa3e3 (you can verify it on https://etherscan.io/token/0xa4eed63db85311e22df4473f87ccfc3dadcfa3e3?a=0x726fc6c8dcc4e291cbc8f9294b89ca2e28ebf57c)4) Go to Rubic Exchange / Uniswap and sync your wallet make sure you set the correct amount of tolerance and gas ect.
#
# https://boards.4channel.org/biz/thread/27139211
# >>27147785You can buy eth on metamask with a credit card I believe.
#
# https://boards.4channel.org/biz/thread/27139211
# >>27139211Want to fomo 2 ETH but fuck those gas fees. What to do?
#
# https://boards.4channel.org/biz/thread/27139211
# >>27148243suck it up anon, eth is only going up and the network is only going to get more congested this year
#
# https://boards.4channel.org/biz/thread/27139211
# >>27151178You need to provide ETH and RBC for a LP. The official one is giving you 8% for 1.5 months, 20% interest for 3 months.
#
# https://boards.4channel.org/biz/thread/27139211
# >>27152203Also to stake it (and make a cut of the fees), you need the equivalent value in ETH. So if Rubic skyrockets, you'd make more holding more RBC (instead of the ETH) anyway
#
# https://boards.4channel.org/biz/thread/27139211
# >0.0152 ETH>cant buy 000.1 RBC
#
# https://boards.4channel.org/biz/thread/27139211
# tfw i would be swinging so hard right now if gas wasnt FUCKING 250 GWEI WTF ETH IS SO FUCKING FUCKED UP AND STUPID AHHHHHdoes rubic have any plans to integrate xdai? or how do they claim to get low gas fees? how does it work?
#
# https://boards.4channel.org/biz/thread/27139211
# >>27139211Hey frens. I have 0.6 ETH laying around. Should I trade in my ETH for RBC? What do you guys think?
#
# https://boards.4channel.org/biz/thread/27144964
# I think especially in the DeFi age you should look at the new DEXs separately. So I wouldn't name RBC and DEXG in the same breath as BTC, ETH or Chainlink, but they definitely have great potential
#
# https://boards.4channel.org/biz/thread/27144964
# >>27152055Just use binance US, or buy eth on coinbase with USD and use uniswap with a meta mask wallet. good luck
#
# https://boards.4channel.org/biz/thread/27144964
# >>27152571unrionically kill yourself it's a dead 2017 scam with no user and no dapps you got china hustled there are two relevant blockchains, btc and eth. anything is brainlet bait. Name one relevant protocol built on Neo--- you cannot. Eth has Uni, Aave, SNX, Comp, Maker, and many others with over a billion in action in them and all will be over $100 billion by the eoy. Neo has nothing. At least justin sun copy pastes relevant eth dapps even tho no one uses them or cares.
#
# https://boards.4channel.org/biz/thread/27144964
# >>27152984i dunno, with using programming languages devs are accustom too, and NEO 3.0 enabling an all-in-one platform for dApp devs and users, incredibly low GAS fees, im gonna hold until March and see what happens... it seems like a very undervalued coin that has many advantages over eth
#
# https://boards.4channel.org/biz/thread/27144964
# New to cryptos here. I have 3k to invest and was considering put them in ETH. I'm not especially looking for short term huge profit and can wait a few years.Should I put those 3k in eth or should I put 2k in eth and 1k in other promising cryptos?
#
# https://boards.4channel.org/biz/thread/27144964
# norubers are the saltiest MFers on the planet. All they had to do was listen. I turned 3 ETH into $30k and I still have 200k RBC left over to hold for years. Thank you based /biz/ anons who sold me on Rubic early
#
# https://boards.4channel.org/biz/thread/27144964
# >>27144964>ETH>Polkadotnot shitcoins
#
# https://boards.4channel.org/biz/thread/27155066
# >>27155066I sold all my ETH yesterday at $1400.
#
# https://boards.4channel.org/biz/thread/27155066
# Just be patient, ETH 2.0 will be completed within 5 years.
#
# https://boards.4channel.org/biz/thread/27155066
# >>27155759Impossible because no one will trust anything that isn't well established, ETH is effectively preventing any forward development of blockchain as the Lotto dude just found out.Also this shit is giving Robinhood almost total control over entry into the crypto investment market.
#
# https://boards.4channel.org/biz/thread/27155066
# >>27156022Many new projects are solving this problem, the problem is literally eth and btc can't innovate fast enough.
#
# https://boards.4channel.org/biz/thread/27155066
# Sitting here with 40$ worth of mined ETH, can't even lose it on hottest scams because of gas. Sad.Although i understand that me having those 40$ is the reason why i can't spend it, still, the whole thing feels pointless.
#
# https://boards.4channel.org/biz/thread/27155066
# >>27155066because right now you're supposed to be making big moves with ETH. That's like buying a cup of coffee with gold bullion, you're using it the wrong way.A coin like ALGO is more realistic for the next gen when it handles everyday expenses: fast, stakeable and with low power consumption
#
# https://boards.4channel.org/biz/thread/27155066
# >>27155944XLM would be a great platform for transfers, hate it or love it, that shit takes seconds to transfer and costs nearly nothing.meanwhile I dropped 2 ETH into RBC and wasted $50 in gas
#
# https://boards.4channel.org/biz/thread/27155066
# >>2716125790% of the crypto space wouldn't exist without itthis would be a dead space after bitcoins initial run if eth wasn't around
#
# https://boards.4channel.org/biz/thread/27155066
# >>27161688cool we'll just stop accepting ETH and related transactions, I'm sure the grocery store will take your QR code for groceries
#
# https://boards.4channel.org/biz/thread/27155066
# >>27155606you don't know the purpose of eth, do you? Pro tip: is not replacing fiat
#
# https://boards.4channel.org/biz/thread/27155066
# >>27162204you're right anon, crypto is for paying fees on crypto on fees on cryptoits eth peeing on eth all the way down
#
# https://boards.4channel.org/biz/thread/27155066
# ETH is gay, DOT, KSM, and ATOM are way better.Disclosure: This poster owns DOT, KSM, and ATOM
#
# https://boards.4channel.org/biz/thread/27155066
# >>27162379>>27162204At this point ETH IS fiat, worse really since it doesn't even have government force backing it. India is about to prove how utterly worthless it is.
#
# https://boards.4channel.org/biz/thread/27155066
# So just tried buying ETH shitcoins shilled here for the first time today bought 200€ of ETH.Bought said shitcoins with ETH with metamask on uniswap now my wallet is only worth 2/3 of its value in USD after trading fees/gas fees.I can see op's point
#
# https://boards.4channel.org/biz/thread/27155066
# >>27155667Dumb fuck. Eth price discovery next week. 3x
#
# https://boards.4channel.org/biz/thread/27159445
# >>27159795Ya that’s true but it happened to eth and you see what happened. Normies suck tho it’s still our coin for sure
#
# https://boards.4channel.org/biz/thread/27159445
# >>27159445it's going to dump to $15-18 before we see an ATH. BTC is going to dump soon, ETH is double top (that will turn into cup and handle before the bullrun continues). Q2 2021 is going to be bearish for crypto. I'd look into Q4, 22 Q1 for continuation of bull market
#
# https://boards.4channel.org/biz/thread/27159445
# >>27163748VRF and Arbitrum are incredibly valuable and the big players are finally starting to launch their products - SWIFT, JP Morgan etc. I don't see how this couldn't justify a massive price increase. $250 is only a 10x from here and being the backbone of the blockchain and allowing it to function at peak performance has to be worth at least half as much as ETH and that's not even considering staking and enterprise adoption. Maybe I'm optimistic and tired but I've held for over two years and I can't see how Link proving functionality and gaining adoption in the middle of the bull cycle won't cause extreme upward movement. Maybe after the cycle it corrects down to a more "reasonable" valuation but I don't see why it doesn't mean the sky is the limit for the next 9 or so months
#
# https://boards.4channel.org/biz/thread/27155793
# When the fuck is ETH going to pump? Literally everything has pumped including BTC. When is ETH going to finally break above its all time high?

# %%
# Print posts about the top coin
top_rated_coin_ticker = coin_freq_dict[0][1]
print_title('Printing messages related to most mentiond coin: ' + top_rated_coin_ticker)
print_posts_mentioning_coin(top_rated_coin_ticker, all_posts_by_thread_dict)
